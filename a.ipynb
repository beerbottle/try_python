# %%
import os
os.system('cls')
# Out:
# 0

# %%
import os
os.system('cls')
# Out:
# 0

# %%
os.system('cls')
# Out:
# 0

# %%
a=100

# %%
import wtf_python as wd

# %%
a='wtf_woalrus'

# %%
a
# Out:
# 'wtf_woalrus'

# %%
some_func()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-3d9630d20b3d> in <module>
# ----> 1 some_func()
#
# NameError: name 'some_func' is not defined

# %%
wd
# Out:
# <module 'wtf_python' from 'd:\\Users\\Leeman\\Anaconda3\\lib\\site-packages\\wtf_python\\__init__.py'>

# %%
wd.fetch_updated_doc()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-a2409cad6b5f> in <module>
# ----> 1 wd.fetch_updated_doc()
#
# AttributeError: module 'wtf_python' has no attribute 'fetch_updated_doc'

# %%
wtfpython
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-ed0538edda7c> in <module>
# ----> 1 wtfpython
#
# NameError: name 'wtfpython' is not defined

# %%
WTF() is WTF()
# Out:
# I
# I
# D
# D
# False

# %%
from wtf_python import *

# %%
class WTF(object):
    def __init__(self): print("I")
    def __del__(self): print("D")
